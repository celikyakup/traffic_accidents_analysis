# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("C://Users/yako_/Downloads/accidents_2005_to_2007.csv",low_memory=False)
df2=pd.read_csv("C://Users/yako_/Downloads/accidents_2009_to_2011.csv",low_memory=False)
df3=pd.read_csv("C://Users/yako_/Downloads/accidents_2012_to_2014.csv",low_memory=False)

# %%
df1.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  04/01/2005  ...
# ...

# %%
df2.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200901BS70001                 524910                  180800  -0.201349
# 1  200901BS70002                 525050                  181040  -0.199248
# 2  200901BS70003                 526490                  177990  -0.179599
# 3  200901BS70004                 524800                  180300  -0.203110
# 4  200901BS70005                 526930                  177490  -0.173445
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.512273             1                  2                   2
# 1  51.514399             1                  2                   2
# 2  51.486668             1                  3                   2
# 3  51.507804             1                  2                   2
# 4  51.482076             1                  2                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  01/01/2009  ...
# ...

# %%
df3.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
df1.shape,df2.shape,df3.shape
# Out:
# ((570011, 33), (469442, 33), (464697, 33))

# %%
df=pd.concat([df1,df2,df3],axis=0)

# %%
df
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200501BS00001               525680.0                178240.0
# 1       200501BS00002               524170.0                181650.0
# 2       200501BS00003               524520.0                182240.0
# 3       200501BS00004               526900.0                177530.0
# 4       200501BS00005               528060.0                179040.0
# ...               ...                    ...                     ...
# 464692       2.01E+12               310037.0                597647.0
# 464693       2.01E+12               321509.0                574063.0
# 464694       2.01E+12               321337.0                566365.0
# 464695       2.01E+12               323869.0                566853.0
# 464696       2.01E+12               314072.0                579971.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.191170  51.489096             1                  2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1504150 entries, 0 to 464696
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Accident_Index                               1504150 non-null  object
#  1   Location_Easting_OSGR                        1504049 non-null  float64
#  2   Location_Northing_OSGR                       1504049 non-null  float64
#  3   Longitude                                    1504049 non-null  float64
#  4   Latitude                                     1504049 non-null  float64
#  5   Police_Force                                 1504150 non-null  int64
#  6   Accident_Severity                            1504150 non-null  int64
#  7   Number_of_Vehicles                           1504150 non-null  int64
#  8   Number_of_Casualties                         1504150 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Accident_Index                                       0
# Location_Easting_OSGR                              101
# Location_Northing_OSGR                             101
# Longitude                                          101
# Latitude                                           101
# Police_Force                                         0
# Accident_Severity                                    0
# Number_of_Vehicles                                   0
# Number_of_Casualties                                 0
# Date                                                 0
# Day_of_Week                                          0
# Time                                               117
# Local_Authority_(District)                           0
# Local_Authority_(Highway)                            0
# 1st_Road_Class                                       0
# 1st_Road_Number                                      0
# Road_Type                                            0
# ...

# %%
df.Time
# Out:
# 0         17:42
# 1         17:36
# 2         00:15
# 3         10:35
# 4         21:13
#           ...
# 464692    22:20
# 464693    06:40
# 464694    02:00
# 464695    06:55
# 464696    15:00
# Name: Time, Length: 1504150, dtype: object

# %%
df["Carriageway_Hazards"].value_counts()
# Out:
# None                                       1476871
# Other object in carriageway                  11762
# Any animal (except a ridden horse)            8014
# Pedestrian in carriageway (not injured)       3586
# Involvement with previous accident            2282
# Dislodged vehicle load in carriageway         1606
# Name: Carriageway_Hazards, dtype: int64

# %%
df["Special_Conditions_at_Site"].value_counts()
# Out:
# None                                               1467553
# Roadworks                                            17223
# Ol or diesel                                          5243
# Mud                                                   4610
# Road surface defective                                3664
# Auto traffic singal out                               2788
# Permanent sign or marking defective or obscured       2269
# Auto traffic signal partly defective                   785
# Name: Special_Conditions_at_Site, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Speed_limit",hue="Accident_Severity",data=df)
plt.title("The severity of the accident according to the speed limit")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Weather_Conditions",hue="Accident_Severity",data=df)
plt.title("accident severity according to weather conditions")
plt.legend(title="Accident Severity",labels=["Fatal","Serious","Slight"])
plt.show()

# %%
sns.relplot(data=df,x="Longitude",y="Latitude")

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Day_of_Week",data=df)
plt.title("Number of Accident by Days of week")
plt.xlabel("Days of week")
plt.ylabel("Number of Accident")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Year",data=df)
plt.title("Number of Accident by years")
plt.xlabel("Year")
plt.ylabel("Number of Accident")
plt.show()

# %%
plt.figure(figsize=(22,10))
sns.countplot(x="Road_Surface_Conditions",hue="Year",data=df)
# Out:
# <AxesSubplot:xlabel='Road_Surface_Conditions', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Road_Type",data=df,hue="Accident_Severity")
plt.title("Accident Severity by road type")
plt.xlabel("Road Type")
plt.ylabel("Number of Accident")
plt.legend(title="Accident Severity",labels=["Fatal","Serious","Slight"])
plt.show()
